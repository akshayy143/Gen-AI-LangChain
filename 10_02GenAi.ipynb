# %% [markdown]
# ![Screenshot 2026-06-24 151208.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-06-24 151259.png](data:image/png;base64,...)

# %% [markdown]
# link of code - https://github.com/campusx-official/langchain-runnables

# %% [markdown]
# link of drive - https://colab.research.google.com/drive/1P11hpAPtjr0oIiqQ5pNsdnMxmascdbBY?usp=sharing

# %% [markdown]
# link - https://colab.research.google.com/drive/1gv3e-OfHCi6IuVBVR7xWmrcVl6gHsydv?usp=sharing

# %% [markdown]
# ![Screenshot 2026-06-24 153052.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-06-24 153318.png](data:image/png;base64,...)
