# %% [markdown]
# link for code of this lecture - https://github.com/campusx-official/langchain-structured-output

# %% [markdown]
# ![Screenshot 2026-06-10 091425.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-06-10 094534.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-06-10 095505.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-06-10 095526.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-06-10 095542.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-06-10 095645.png](data:image/png;base64,...)
