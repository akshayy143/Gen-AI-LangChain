# %% [markdown]
# # Syllubus

# %% [markdown]
# ![Screenshot 2026-05-29 165654.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-05-29 170015.png](data:image/png;base64,...)![Screenshot 2026-05-29 170040.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-05-29 170402.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-05-29 170427.png](data:image/png;base64,...)
