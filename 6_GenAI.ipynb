# %% [markdown]
# ![Screenshot 2026-06-05 192721.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-06-05 192922.png](data:image/png;base64,...)

# %% [markdown]
# code github link practice it ASAP- https://github.com/campusx-official/langchain-prompts

# %% [markdown]
# this is result of code

# %% [markdown]
# ![Screenshot 2026-06-05 193301.png](data:image/png;base64,...)

# %% [markdown]
# #### Dynamic Prompt

# %% [markdown]
# ![Screenshot 2026-06-05 193346.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-06-05 194225.png](data:image/png;base64,...)

# %% [markdown]
# ## type  of message in langchain

# %% [markdown]
# system message
#
# human message
#
# AI message

# %% [markdown]
# ![Screenshot 2026-06-05 195851.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-06-05 200440.png](data:image/png;base64,...)
