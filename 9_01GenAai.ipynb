# %% [markdown]
# ![Screenshot 2026-06-20 150905.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-06-20 151016.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-06-20 151142.png](data:image/png;base64,...)

# %% [markdown]
# code of this lecture - https://github.com/campusx-official/langchain-chains

# %% [markdown]
# ![Screenshot 2026-06-20 152000.png](data:image/png;base64,...)

# %%
model1 = chatopenAI()

# %% [markdown]
# ![Screenshot 2026-06-20 152735.png](data:image/png;base64,...)
