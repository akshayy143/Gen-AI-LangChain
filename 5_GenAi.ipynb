# %% [markdown]
# ![Screenshot 2026-06-03 154647.png](data:image/png;base64,...)![Screenshot 2026-06-03 154132.png](data:image/png;base64,...)![Screenshot 2026-06-03 154504.png](data:image/png;base64,...)![Screenshot 2026-06-03 154154.png](data:image/png;base64,...)
