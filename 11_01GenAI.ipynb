# %% [markdown]
# ![Screenshot 2026-06-30 153402.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-06-30 153439.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-06-30 153502.png](data:image/png;base64,...)

# %% [markdown]
# link - https://github.com/campusx-official/langchain-runnables

# %% [markdown]
# ![Screenshot 2026-06-30 153808.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-06-30 154026.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-06-30 154435.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-06-30 154845.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-06-30 155358.png](data:image/png;base64,...)

# %%
also  lcel topic by
