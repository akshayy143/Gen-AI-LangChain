# %% [markdown]
# ![Screenshot 2026-06-16 101222.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-06-16 101337.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-06-16 101518.png](data:image/png;base64,...)

# %% [markdown]
# link of code - https://github.com/campusx-official/langchain-output-parsers

# %% [markdown]
# ![Screenshot 2026-06-16 103002.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-06-16 103454.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-06-16 103919.png](data:image/png;base64,...)
