# %% [markdown]
# ![Screenshot 2026-05-30 192147.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-05-30 192631.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-05-30 192458.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-05-30 192606.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-05-30 192718.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-05-30 192745.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-05-30 192925.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-05-30 193034.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-05-30 193123.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-05-30 193624.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-05-30 193609.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-05-30 193808.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-05-30 194201.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-05-30 194321.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-05-30 194713.png](data:image/png;base64,...)
