# %% [markdown]
# # GEN AI  INTRO

# %% [markdown]
# ![Screenshot 2026-05-29 163335.png](data:image/png;base64,...)![Screenshot 2026-05-29 162950.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-05-29 164550.png](data:image/png;base64,...)![Screenshot 2026-05-29 164116.png](data:image/png;base64,...)![Screenshot 2026-05-29 164250.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-05-29 164842.png](data:image/png;base64,...)![Screenshot 2026-05-29 165003.png](data:image/png;base64,...)
